# %%
# !pip install git+https://github.com/daviromero/anita.git -q
# !pip install git+https://github.com/daviromero/nadia.git -q
from anita.anita_pt_gui import anita, anita_theorem
from nadia.nadia_pt_gui import nadia, nadia_theorem
# Out:
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 20.2 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...

# %%
#@title Questão 1 (1.25 pontos) Demonstre em Dedução Natural (NADIA)
#@markdown Execute essa célula para gerar o seu exercício.

nadia_theorem(input_theorem='~A->B, A->C,~B |- C')
# Out:
# HTML(value='<h3>Digite a demonstração de ~A->B, A->C,~B |- C em Dedução Natural:</h3>')
# Textarea(value='', layout=Layout(height='300px', width='90%'), placeholder='Digite sua demonstração:')
# ...
# Output()

# %%
#@title Questão 2 (1.25 pontos) Demonstre em Tableau Analítico (ANITA)
#@markdown Execute essa célula para gerar o seu exercício.

anita_theorem(input_theorem='~A->B, A->C,~B |- C')
# Out:
# HTML(value='<h3>Digite a demonstração de ~A->B, A->C,~B |- C em Tableau Analítico:</h3>')
# Textarea(value='', layout=Layout(height='300px', width='90%'), placeholder='Digite sua demonstração:')
# ...
# Output()

# %%
#@title Questão 3 (1.25 pontos) Demonstre em Dedução Natural (NADIA)
#@markdown Execute essa célula para gerar o seu exercício.

nadia_theorem(input_theorem='A->(B->~C), B|- ~A|~C')
# Out:
# HTML(value='<h3>Digite a demonstração de A->(B->~C), B|- ~A|~C em Dedução Natural:</h3>')
# Textarea(value='', layout=Layout(height='300px', width='90%'), placeholder='Digite sua demonstração:')
# ...
# Output()

# %%
#@title Questão 4 (1.25 pontos) Demonstre em Tableau Analítico (ANITA)
#@markdown Execute essa célula para gerar o seu exercício.

anita_theorem(input_theorem='A->(B->~C), B|- ~A|~C')
# Out:
# <font color="blue">Parabéns! A demonstraçãoo de A->(B->~C), B |- ~A|~C está correta.</font>
# HTML(value='')

# %%
#@title Questão 5 (1.25 pontos) Demonstre em Dedução Natural (NADIA)
#@markdown Execute essa célula para gerar o seu exercício.

nadia_theorem(input_theorem='~A->~B, B->D,(A&D)->~C |- B->~C')
# Out:
# HTML(value='<h3>Digite a demonstração de ~A->~B, B->D,(A&D)->~C |- B->~C em Dedução Natural:</h3>')
# Textarea(value='', layout=Layout(height='300px', width='90%'), placeholder='Digite sua demonstração:')
# ...
# Output()

# %%
#@title Questão 6 (1.25 pontos) Demonstre em Tableau Analítico (ANITA)
#@markdown Execute essa célula para gerar o seu exercício.

anita_theorem(input_theorem='~A->~B, B->D,(A&D)->~C |- B->~C')
# Out:
# HTML(value='<h3>Digite a demonstração de ~A->~B, B->D,(A&D)->~C |- B->~C em Tableau Analítico:</h3>')
# Textarea(value='', layout=Layout(height='300px', width='90%'), placeholder='Digite sua demonstração:')
# ...
# Output()

# %%
#@title Questão 7 (1.25 pontos) Demonstre em Dedução Natural (NADIA)
#@markdown Execute essa célula para gerar o seu exercício.
input_text_assumptions=['Se o dólar sobe ou o petróleo sobe, então não compro mais comida.', 'Se tenho aumento, então compro mais comida.','O dólar sobe.']
input_text_conclusion='Não tive aumento.'
nadia(input_text_assumptions=input_text_assumptions,input_text_conclusion=input_text_conclusion )
# Out:
# <font color="blue">Parabéns! A demonstração de (D|P)->~C, A->C, D |- ~A está correta.</font>
# HTML(value='')

# %%
#@title Questão 8 (1.25 pontos) Demonstre em Tableau Analítico (ANITA)
#@markdown Execute essa célula para gerar o seu exercício.
input_text_assumptions=['Se o dólar sobe ou o petróleo sobe, então não compro mais comida.','Se tenho aumento, então compro mais comida.','O dólar sobe.']
input_text_conclusion='O petróleo sobe.'
anita(input_text_assumptions=input_text_assumptions,input_text_conclusion=input_text_conclusion )
# Out:
# <b>Considere as seguintes afirmações:</b>
# 1. Se o dólar sobe ou o petróleo sobe, então não compro mais comida.
# 1. Se tenho aumento, então compro mais comida.
# 1. O dólar sobe.
# <b>Considere a afirmação abaixo segue logicamente das afirmações acima:
# 4. O petróleo sobe.
# ### Represente as afirmações acima em lógica e digite sua demonstração em Tableau Analítico:
# Textarea(value='# Representamos as afirmações através das seguintes fórmulas:\n# 1. ... para "Se o dólar sobe …
# ...
# Output()
